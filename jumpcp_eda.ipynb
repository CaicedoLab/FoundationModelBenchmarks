# %%
import pandas as pd

df = pd.read_parquet("/scr/data/jumpcp/BR00116991.pq")

# %%
df
# Out:
#                          ID  start_x  start_y  end_x  end_y  field_id  row  \
# 0       BR00116991_A01_1_12      150       17    374    241         1    1
# 1       BR00116991_A01_1_13       40       39    264    263         1    1
# 2       BR00116991_A01_1_15      230       68    454    292         1    1
# 3       BR00116991_A01_1_16       48       73    272    297         1    1
# 4       BR00116991_A01_1_18       79       82    303    306         1    1
# ...                     ...      ...      ...    ...    ...       ...  ...
# 229223  BR00116991_P24_9_87      572      808    796   1032         9   16
# 229224  BR00116991_P24_9_88      445      819    669   1043         9   16
# 229225  BR00116991_P24_9_89      540      825    764   1049         9   16
# 229226  BR00116991_P24_9_91      617      835    841   1059         9   16
# 229227  BR00116991_P24_9_93      356      838    580   1062         9   16
#
#         column well_loc    plate_id  \
# ...

# %%
compound_metadata = pd.read_csv("/scr/data/jumpcp/platemap_and_metadata/JUMP-Target-2_compound_metadata.tsv", sep="\t")
compound_metadata
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 compound_metadata = pd.read_feather("/scr/data/jumpcp/platemap_and_metadata/JUMP-Target-2_compound_metadata.tsv")
#       2 compound_metadata
#
# File /scr/vidit/anaconda3/lib/python3.11/site-packages/pandas/io/feather_format.py:124, in read_feather(path, columns, use_threads, storage_options, dtype_backend)
#     120 with get_handle(
#     121     path, "rb", storage_options=storage_options, is_text=False
#     122 ) as handles:
#     123     if dtype_backend is lib.no_default and not using_pyarrow_string_dtype():
# --> 124         return feather.read_feather(
#     125             handles.handle, columns=columns, use_threads=bool(use_threads)
#     126         )
#     128     pa_table = feather.read_table(
#     129         handles.handle, columns=columns, use_threads=bool(use_threads)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
pd = np.load("/scr/data/jumpcp/BR00116991/BR00116991_M10_1_34.npy")


plt.imshow(pd[5, :, :], cmap="gray")

# %%
pd.shape
# Out:
# (8, 224, 224)
